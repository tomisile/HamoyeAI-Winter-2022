# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
from statistics import mean, median, mode, stdev

# %% [markdown]
# ### Importing dataset

# %%
dataset = pd.read_csv(r"C:\\Users\Tomi\Downloads\FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding='latin1')
dataset.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# ### Sum of Animal Fat produced in 2014 and 2017 respectively

# %%
dataset.groupby('Item')['Y2014'].sum().loc['Animal fats']
# Out:
# 209460.54

# %%
dataset.groupby('Item')['Y2017'].sum().loc['Animal fats']
# Out:
# 269617.53

# %% [markdown]
# ### Mean and Standard Deviation

# %%
dataset['Y2016'].mean()
# Out:
# 136.55522236062103

# %%
dataset['Y2016'].std()
# Out:
# 1640.0071942671407

# %% [markdown]
# ### Highest sum of import quantity

# %%
sub_dataset_1 = dataset.groupby('Element').sum()
sub_dataset_1
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
sub_dataset_1.loc['Import Quantity'].max()
# Out:
# 28834929.0

# %% [markdown]
# ### Total Number of sum of production in 2014

# %%
dataset.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
dataset.groupby('Element')['Y2014'].sum().loc['Production']
# Out:
# 1931287.75

# %% [markdown]
# ### Sum in 2018 (highest and third lowest)

# %%
sub_dataset_2 = dataset[['Y2018', 'Element']]
sub_dataset_2.groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %%
# Highest
sub_dataset_2.groupby('Element')['Y2018'].sum().max()
# Out:
# 2161192.1

# %%
# Third lowest
sub_dataset_2.groupby('Element')['Y2018'].sum().nsmallest(3)
# Out:
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Name: Y2018, dtype: float64

# %% [markdown]
# ### Number of unique countries

# %%
dataset['Area'].nunique()
# Out:
# 49
